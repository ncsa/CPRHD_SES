# %%
import numpy as np
import pandas as pd
import time

# %%
data_dir = "BeckyData/"
final_file = pd.read_csv(data_dir + "final.csv")

# %%
final_file
# Out:
#          hexid  FID_other  Input_FID      tempc      preci    yr  weeks  \
# 0       3945.0        814       5966   9.426700   2.126910  2005     18
# 1       3945.0        814       5966  15.422600  21.774270  2005     19
# 2       3945.0        814       5966  14.090200  30.985240  2005     20
# 3       3945.0        814       5966  16.664200   1.182440  2005     21
# 4       3945.0        814       5966  17.052000   0.880722  2005     22
# 5       3945.0        814       5966  25.592600  15.095516  2005     23
# 6       3945.0        814       5966  21.545200   2.283651  2005     24
# 7       3945.0        814       5966  23.255200   0.000000  2005     25
# 8       3945.0        814       5966  26.181700   2.088355  2005     26
# 9       3945.0        814       5966  22.483900   5.257170  2005     27
# 10      3945.0        814       5966  25.459100   1.272924  2005     28
# 11      3945.0        814       5966  26.500100  17.722900  2005     29
# ...

# %%
final_file.columns
# Out:
# Index(['hexid', 'FID_other', 'Input_FID', 'tempc', 'preci', 'yr', 'weeks',
#        'yrweeks', 'yrwksfid', 'templag1', 'templag2', 'templag3', 'templag4',
#        'precilag1', 'precilag2', 'precilag3', 'precilag4', 'MIRMEAN_1',
#        'YEAR_1', 'MIRLAG1_1', 'MIRLAG2_1', 'MIRLAG3_1', 'MIRLAG4_1', 'totpop',
#        'whitepct', 'blackpct', 'asianpct', 'hispanicpct', 'Income', 'owpct',
#        'dospct', 'dlipct', 'dmipct', 'dhipct', 'blpct', 'dfpct', 'efpct',
#        'mfpct', 'shrubpct', 'glandpct', 'pasturepct', 'ccpct', 'wwpct',
#        'ehwpct', 'yr_hexid', 'yr_hexid_wk', 'Jantemp', 'hpctpreww',
#        'hpctpreww_1', 'hpctpostww', 'hpct7089', 'hpctpost90', 'LTFID',
#        'LTCOUNT', 'LTAREA', 'LTMIN', 'LTMAX', 'LTRANGE', 'LTMEAN', 'LTSTD',
#        'LTSUM', 'GTFID', 'GTCOUNT', 'GTAREA', 'GTMIN', 'GTMAX', 'GTRANGE',
#        'GTMEAN', 'GTSTD', 'GTSUM', 'CB', 'YR_HEXID_W'],
#       dtype='object')
