# %%
import pickle
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import log_loss
from sklearn.metrics import roc_auc_score
import numpy as np
import time
import scipy.stats as stats
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.linear_model import LinearRegression
from scipy import stats
from sklearn.metrics import log_loss
from sklearn.calibration import CalibratedClassifierCV, calibration_curve
import matplotlib.pyplot as plt
from sklearn.metrics import (brier_score_loss, precision_score, recall_score,
                             f1_score)

# %%
len(data.columns)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b437e615865f> in <module>
# ----> 1 len(data.columns)
#
# NameError: name 'data' is not defined

# %%
data = pd.read_sas('/home/guangya/Downloads/wnv_2245new.sas7bdat')

# %%
data[(data.yr == 2011) & (data.weeks == 29)].tempc.max()
# Out:
# 29.7265142857143

# %%
data[(data['tempc'] <= 15.5)].weeks.value_counts()
# Out:
# 45.0    60204
# 44.0    60204
# 43.0    60204
# 42.0    53220
# 41.0    42266
# 40.0    31606
# 39.0    27752
# 38.0    13364
# 22.0     9687
# 23.0     3532
# 37.0     1397
# 35.0      561
# Name: weeks, dtype: int64

# %%
5017 * 12
# Out:
# 60204

# %%
(data[data.weeks == 17]['tempc'] < 29).sum()
# Out:
# 0

# %%
model = pickle.load(open('/home/guangya/Downloads/RF_model_CV_final_1_22_2020', 'rb'))

# %%
home/jallen17/CPRHD_SES/RF_model_fimodel.best_estimator_
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=100, max_features='sqrt', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=10, min_samples_split=4,
#                        min_weight_fraction_leaf=0.0, n_estimators=1600,
#                        n_jobs=-1, oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)

# %%
model.pre

# %%
agg = pd.read_csv('/home/guangya/Downloads/Agg_mirdata (1).csv',index_col = False)

# %%
agg0 = pd.read_csv('/home/guangya/Downloads/Agg_mirdata_new.csv',index_col = False)

# %%
agg = agg.drop(columns= agg.columns[[1,5,7,6,8,9,10,11,12,15,16,17,18,-1,-6]])

# %%
agg.columns
# Out:
# Index(['yr', 'hexid', 'tempc', 'preci', 'wnvbinary', 'mirmean', 'totpop',
#        'whitepct', 'blackpct', 'asianpct', 'hispanicpct', 'Income', 'owpct',
#        'dospct', 'dlipct', 'dmipct', 'dhipct', 'blpct', 'dfpct', 'efpct',
#        'mfpct', 'shrubpct', 'glandpct', 'pasturepct', 'ccpct', 'wwpct',
#        'ehwpct', 'Jantemp', 'hpctpreww', 'hpctpostww', 'hpct7089',
#        'hpctpost90'],
#       dtype='object')

# %%
data = agg

# %%
data = data.drop(columns = 'hexid')

# %%
agg.iloc[3900]['wnvbinary'] = 1 # Only exceptions

# %%
x_selected = data.drop(columns = 'wnvbinary')

# %%
l = []

# %%
# Out:
# Input_FID: 6.173820128326637e-23
# tempc: 4.86664555362853e-50
# preci: 0.1610149639838622
# yr: 8.115466302777349e-25
# weeks: 5.424348227645927e-82
# templag1: 5.553095060099412e-93
# templag2: 5.621102894863635e-131
# templag3: 1.2433454527497459e-163
# templag4: 7.44418317262221e-181
# precilag1: 0.1604137622969023
# precilag2: 0.5644103481593911
# precilag3: 0.14449030624211207
# precilag4: 0.042752041558668
# wnvbinary: 0.0
# mirmean: 3.8312348357555006e-196
# mirlag1: 6.761573223118551e-217
# mirlag2: 7.923458795864661e-233
# mirlag3: 1.7338413463587432e-204
# mirlag4: 4.1845128733461916e-179
# totpop: 7.10412100434133e-98
# whitepct: 0.04962040904353546
# blackpct: 4.467968356546985e-05
# asianpct: 4.981946735780371e-06
# hispanicpct: 7.496085632241714e-05
# Income: 0.09945694356945486
# owpct: 2.9717555503674257e-16
# dospct: 5.784435230622255e-19
# dlipct: 2.0963782805825886e-15
# dmipct: 4.295993770341808e-24
# dhipct: 1.3419760192813334e-08
# blpct: 0.4533957260314463
# dfpct: 1.427177356921051e-29
# efpct: 0.6400235073495482
# mfpct: 3.138959993864337e-14
# shrubpct: 0.0038979667253784393
# glandpct: 2.3299247210270896e-21
# pasturepct: 8.231347337835485e-05
# ccpct: 2.4664311445827342e-06
# wwpct: 4.457285771220121e-21
# ehwpct: 0.6246065614741914
# Jantemp: 1.143226596501687e-63
# hpctpreww: 2.0691462422059147e-35
# hpctpostww: 1.9300832583888054e-07
# hpct7089: 2.6389355942461533e-28
# hpctpost90: 1.5628901281031213e-29

# %%
l = []

# %%
for x in agg_0.columns:
    print(x + ': ' + str(stats.ks_2samp(agg_wnv[x], agg_0[x])[1]))
    value = stats.ks_2samp(agg_wnv[x], agg_0[x])[1]
    if(value < 0.01):
        l.append(x)
# Out:
# Input_FID: 6.390213842202285e-07
# tempc: 3.529596088854107e-38
# preci: 6.950997568998862e-06
# yr: 4.034872356380986e-09
# weeks: 3.3018410530629804e-42
# templag1: 1.6075329481971952e-40
# templag2: 6.524223156077696e-46
# templag3: 2.3985008414230865e-40
# templag4: 1.5088000766536422e-37
# precilag1: 0.027885493943262542
# precilag2: 0.5608123364427637
# precilag3: 3.745945877464269e-11
# precilag4: 3.132445075682942e-24
# wnvbinary: 1.2981516909388646e-103
# mirmean: 1.4549509581966023e-54
# mirlag1: 1.9366416927172542e-48
# mirlag2: 7.85066387729148e-42
# mirlag3: 4.015931957483083e-41
# mirlag4: 2.2927963593503358e-33
# totpop: 1.136967814324584e-19
# whitepct: 0.1798101789089166
# blackpct: 0.11853166375855227
# asianpct: 0.10793052934232421
# hispanicpct: 0.02458563452262036
# Income: 0.14265365400704844
# owpct: 0.0017572775675292016
# dospct: 5.3951598287421916e-05
# dlipct: 4.3320124780038627e-07
# dmipct: 0.017010620858381828
# dhipct: 0.00045290546275062425
# blpct: 0.9999995574048837
# dfpct: 4.11509493679482e-05
# efpct: 0.9968668420183502
# mfpct: 0.008163842939583239
# shrubpct: 0.8139652776586157
# glandpct: 0.0002884866490803509
# pasturepct: 0.29577944262966127
# ccpct: 0.21964119082325728
# wwpct: 0.0013227526411622162
# ehwpct: 0.9998851959635338
# Jantemp: 8.794000768982184e-17
# hpctpreww: 1.1348717897524256e-09
# hpctpostww: 0.0019688109857501643
# hpct7089: 3.762156906066812e-08
# hpctpost90: 9.786498634140362e-09

# %%
agg[l]
# Out:
#            yr   hexid      tempc      preci  wnvbinary   mirmean  totpop  \
# 60196   1.664355 -5.737807   1.960784   31.590414  43.464052   22.984749
# 60197   0.000000 -5.666843   1.960784   31.590414  43.464052   22.984749
# 60198   9.015257 -5.571433   1.960784   31.590414  43.464052   22.984749
# 60199   1.248266 -5.486551   3.798768   19.404517  62.012320   14.784394
# 60200   0.000000 -5.428299   2.278748    9.303909  62.221046   26.196297
# 60201   0.000000 -5.369809   5.847054   10.571148  78.789127    4.792671
# 60202   0.000000 -5.271670   0.379381    4.746522  81.840877   13.033219
# 60203   3.883495 -5.172956   0.000000   35.839029  57.988542    6.172429
#
# [60204 rows x 19 columns]

# %%
agg.head()
# Out:
#        yr  hexid     tempc      preci  wnvbinary   mirmean  totpop   whitepct  \
# 0  2005.0    1.0  23.32149  16.957485        0.0  2.216162    59.0  65.742570
# 1  2005.0    2.0  23.45984  17.876777        0.0  0.458950    17.0  69.339933
# 2  2005.0    3.0  23.46203  18.274359        0.0  0.725247     7.0  78.855221
# 3  2005.0    4.0  23.46490  18.632063        0.0  1.015216    84.0   2.990599
# 4  2005.0    5.0  23.46779  18.990706        0.0  1.247546   377.0   8.928929
#
#     blackpct  asianpct  ...  glandpct  pasturepct      ccpct      wwpct  \
# 0  27.679862  1.313306  ...  2.635229   11.234397   0.416089  27.184466
# 1   8.012057  0.000000  ...  5.963939   25.381415  54.091540   0.000000
# 2  10.428884  0.000000  ...  7.628294   17.337032  50.069348   0.000000
# 3  93.380697  0.000000  ...  4.993065    1.664355  57.004161   0.000000
# 4  87.727250  0.721309  ...  4.576976    0.000000  43.273232   0.000000
#
#    ehwpct   Jantemp  hpctpreww  hpctpostww   hpct7089  hpctpost90
# 0     0.0 -3.815482   0.000000    0.000000   0.000000    0.000000
# 1     0.0 -3.963282   0.000000    0.000000  33.779264   66.220736
# 2     0.0 -3.988996   2.457007    6.449643  46.447779   44.645571
# 3     0.0 -3.984824   2.515723    6.603774  46.750524   44.129979
# 4     0.0 -3.980488   6.036512    7.853077  41.809508   44.300903
#
# [5 rows x 32 columns]

# %%
x_selected = data.drop(columns = 'wnvbinary')
y_selected = data['wnvbinary'].values

trainX_sel, testX_sel, trainY_sel, testY_sel = train_test_split(x_selected, y_selected, test_size=0.2, random_state=1) # CV
time_start = time.time()
model_RF_best_2 = RandomForestClassifier(n_estimators=1600,
                                         n_jobs=-1,
                                         max_features='sqrt',
                                         max_depth=100,
                                         min_samples_leaf = 10,
                                         min_samples_split = 4,
                                         bootstrap=True)

# %%
model_RF_best_2.fit(trainX_sel, trainY_sel)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=100, max_features='sqrt', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=10, min_samples_split=4,
#                        min_weight_fraction_leaf=0.0, n_estimators=1600,
#                        n_jobs=-1, oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)

# %%
def model_RF_test(model_RF, dataX, dataY, selectedX):
    print("Model performance")
    predict_data = model_RF.predict_proba(dataX)

    # Some stats
    print("Feature Importance : ")
    feature_importances = pd.DataFrame(model_RF.feature_importances_, index = selectedX.columns, columns=['importance'])
    print(model_RF.feature_importances_)
    print("Total number of WNV occurrence in test set : " + str(len(dataY[dataY > 0])))

    print("Number of WNV occurrence the model is able to capture in test set:" + str(
        dataY[np.where(predict_data[:, 1] > 0)].sum()))

    print("Log loss : " + str(log_loss(dataY, predict_data)))
 
    print("AUC: " + str(roc_auc_score(dataY, predict_data[:,1])))

    print(
        "This is to test the performance of random forest model, ideally, the logloss is low and also it is able to "
        "capture most of the WNV occurrence")

    return None  # Check how many wnv it predicts

# model_RF_test(model_RF_best_2,testX_sel,testY_sel,x_selected)

# %%
model_RF_test(model_RF_best_2,testX_sel,testY_sel,x_selected)
# Out:
# Model performance
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-178-de078e310bbc> in <module>
# ----> 1 model_RF_test(model_RF_best_2,testX_sel,testY_sel,x_selected)
#
# <ipython-input-164-67c48b9d1390> in model_RF_test(model_RF, dataX, dataY, selectedX)
#       1 def model_RF_test(model_RF, dataX, dataY, selectedX):
#       2     print("Model performance")
# ----> 3     predict_data = model_RF.predict_proba(dataX)
#       4
#       5     # Some stats
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py in predict_proba(self, X)
#     584             classes corresponds to that in the attribute `classes_`.
#     585         """
# --> 586         check_is_fitted(self, 'estimators_')
#     587         # Check data
#     588         X = self._validate_X_predict(X)
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#     912
#     913     if not all_or_any([hasattr(estimator, attr) for attr in attributes]):
# --> 914         raise NotFittedError(msg % {'name': type(estimator).__name__})
#     915
#     916
#
# NotFittedError: This RandomForestClassifier instance is not fitted yet. Call 'fit' with appropriate arguments before using this method.

# %%
model_RF_test(model,testX_sel,testY_sel,x_selected)
# Out:
# Model performance
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-194-d52b17a545f9> in <module>
# ----> 1 model_RF_test(model,testX_sel,testY_sel,x_selected)
#
# <ipython-input-164-67c48b9d1390> in model_RF_test(model_RF, dataX, dataY, selectedX)
#       1 def model_RF_test(model_RF, dataX, dataY, selectedX):
#       2     print("Model performance")
# ----> 3     predict_data = model_RF.predict_proba(dataX)
#       4
#       5     # Some stats
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/utils/metaestimators.py in <lambda>(*args, **kwargs)
#     114
#     115         # lambda, but not partial, allows help() to work with update_wrapper
# --> 116         out = lambda *args, **kwargs: self.fn(obj, *args, **kwargs)
#     117         # update the docstring of the returned function
#     118         update_wrapper(out, self.fn)
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_search.py in predict_proba(self, X)
#     472         """
#     473         self._check_is_fitted('predict_proba')
# --> 474         return self.best_estimator_.predict_proba(X)
#     475
#     476     @if_delegate_has_method(delegate=('best_estimator_', 'estimator'))
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py in predict_proba(self, X)
#     586         check_is_fitted(self, 'estimators_')
#     587         # Check data
# --> 588         X = self._validate_X_predict(X)
#     589
#     590         # Assign chunk of trees to jobs
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py in _validate_X_predict(self, X)
#     357                                  "call `fit` before exploiting the model.")
#     358
# --> 359         return self.estimators_[0]._validate_X_predict(X, check_input=True)
#     360
#     361     @property
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/tree/tree.py in _validate_X_predict(self, X, check_input)
#     400                              "match the input. Model n_features is %s and "
#     401                              "input n_features is %s "
# --> 402                              % (self.n_features_, n_features))
#     403
#     404         return X
#
# ValueError: Number of features of the model must match the input. Model n_features is 44 and input n_features is 19

# %%
# Tomorrow: Build fit/CV model for the aggregated dataset, doing ks test after clearning

# %%
model_RF_best_2.get_params
# Out:
# <bound method BaseEstimator.get_params of RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=80, max_features='sqrt', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=8, min_samples_split=6,
#                        min_weight_fraction_leaf=0.0, n_estimators=1400,
#                        n_jobs=-1, oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)>

# %%
model.best_params_
# Out:
# {'bootstrap': True,
#  'max_depth': 100,
#  'max_features': 'sqrt',
#  'min_samples_leaf': 10,
#  'min_samples_split': 4,
#  'n_estimators': 1600}
