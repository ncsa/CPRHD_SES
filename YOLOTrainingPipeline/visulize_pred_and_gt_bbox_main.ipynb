# %%
import json
import imgaug as ia
ia.seed(1)
# imgaug uses matplotlib backend for displaying images
# %matplotlib inline
from imgaug.augmentables.bbs import BoundingBox, BoundingBoxesOnImage
from imgaug import augmenters as iaa 
# imageio library will be used for image input/output
import imageio
import pandas as pd
import numpy as np
import re
import os
import glob
from util import convertYOLO2Other,read_ith_pred_result_yolo, draw_ground_truth_label, analyze_pred_gt_image

# %%
with open('result_1011.json') as f:
  data = json.load(f)

analyze_pred_gt_image(data, 0, 0.4)
# Out:
# img-33_42.039688,-87.908496.jpg
# [[1.       0.405943 0.506252 0.241572 0.212684 0.405164]
#  [0.       0.       0.       0.       0.       0.      ]
#  [0.       0.137852 0.554331 0.205867 0.346692 0.987298]
#  [0.       0.710342 0.514436 0.214787 0.1682   0.9414  ]
#  [0.       0.413247 0.496745 0.279477 0.241888 0.848989]
#  [0.       0.944898 0.442671 0.102346 0.206605 0.417886]]
# BoundingBoxesOnImage([BoundingBox(x1=182.5005, y1=255.9424, x2=337.1066, y2=392.0602, label=1), BoundingBox(x1=0.0000, y1=0.0000, x2=0.0000, y2=0.0000, label=0), BoundingBox(x1=22.3478, y1=243.8304, x2=154.1027, y2=465.7133, label=0), BoundingBox(x1=385.8871, y1=275.4150, x2=523.3507, y2=383.0630, label=0), BoundingBox(x1=175.0454, y1=240.5126, x2=353.9107, y2=395.3210, label=0), BoundingBox(x1=571.9840, y1=217.1958, x2=637.4854, y2=349.4230, label=0)], shape=(640, 640, 3))
